# %%
import utility_common as common
from utility_bfvariater import *
# %matplotlib inline

# %%
triggerNames = {0: "mu-1b",1:"mu-2b",2:"e-1b",3:"e-2b"}
channelNames = {0: r"$\mu e$",1:r"$\mu \mu$",2:r"$\mu \tau$",3:r"$\mu+jets$",
                4: r"$e e$",5:r"$e \mu$",6:r"$e \tau$",7:r"$e+jets$" }
def plot(source,icata,ch):
    counts  = pd.read_pickle( "../../data/counts/count_.pkl")
    counts1 = pd.read_pickle( "../../data/counts/count_{}Up.pkl".format(source))
    counts2 = pd.read_pickle( "../../data/counts/count_{}Down.pkl".format(source))

    acc = common.matrixToArray(counts.acc[icata][ch][1])
    acc1 = common.matrixToArray(counts1.acc[icata][ch][1])
    acc2 = common.matrixToArray(counts2.acc[icata][ch][1])

    accVar = common.matrixToArray(counts.accVar[icata][ch][1])
    accVar1 = common.matrixToArray(counts1.accVar[icata][ch][1])
    accVar2 = common.matrixToArray(counts2.accVar[icata][ch][1])

    fig, axes = plt.subplots(2, 1,facecolor='w',figsize=(5,6),sharex=True, gridspec_kw={'height_ratios':[4,1]})
    fig.subplots_adjust(hspace=0)

    ax = axes[0]
    centers = np.arange(21)
    ax.plot(centers,acc,'k.',label='nominal')
    ax.bar(centers,acc1-acc2,bottom=acc2,width=1,color='C1',alpha=1,label="envelope {}+-".format(source))
    ax.errorbar(centers,acc1,yerr=sqrt(accVar1),fmt='none', lw=10, mew=0,color='C0',label='statUnc {}+'.format(source))
    ax.errorbar(centers,acc2,yerr=sqrt(accVar2),fmt='none', lw=8, mew=0,color='C2',label='statUnc {}-'.format(source))
    ax.grid(linestyle='--',alpha=0.3)
    ax.set_ylabel("Efficiency")
    ax.legend(fontsize=13)
    title = triggerNames[icata] +" region, "+ channelNames[(icata//2)*4+ch]+" channel, "+source
    ax.set_title(title)

    ax = axes[1]
    res = abs(acc1-acc2)/np.sqrt(accVar1+accVar2)
    ax.bar(centers,res,width=1,color='C1')
    xticksName = common.WWBranchNames()
    plt.xticks(centers,xticksName,fontsize=5)
    ax.set_xlim(-1,21)
    ax.axhline(3,linestyle='--',color='k')
    ax.grid(linestyle='--',alpha=0.3)
    ax.set_ylabel(r"$\frac{|\epsilon_+ - \epsilon_-|}{\sigma_{stat}}$")
    ax.set_xlabel(r"21 $WW$ decay final states")

    plt.savefig("../../plots/ttsyst/icata{}_ch{}_{}.png".format(icata,ch,source),dpi=200)

# %%
for source in ['fsr','isr','meps','ue']:
    for icata in range(4):
        for ch in range(4):
            plot(source,icata,ch)
            plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in set_weight(self, weight)
#     857         try:
# --> 858             weight = int(weight)
#     859             if weight < 0 or weight > 1000:
#
# ValueError: invalid literal for int() with base 10: 'bold'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a8d8607a2781> in <module>()
#       2     for icata in range(4):
#       3         for ch in range(4):
# ----> 4             plot(source,icata,ch)
#       5             plt.close()
#
# <ipython-input-4-544a90b65756> in plot(source, icata, ch)
#      41     ax.set_xlabel(r"21 $WW$ decay final states")
#      42
# ---> 43     plt.savefig("../../plots/ttsyst/icata{}_ch{}_{}.png".format(icata,ch,source),dpi=200)
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     696     fig = gcf()
#     697     res = fig.savefig(*args, **kwargs)
# --> 698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#     700
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2038         if not self._is_idle_drawing:
#    2039             with self._idle_draw_cntx():
# -> 2040                 self.draw(*args, **kwargs)
#    2041
#    2042     def draw_cursor(self, event):
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1138                                                                 renderer)
#    1139
#    1140         for tick in ticks_to_draw:
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1076         for tick in ticks:
#    1077             if tick.label1On and tick.label1.get_visible():
# -> 1078                 extent = tick.label1.get_window_extent(renderer)
#    1079                 ticklabelBoxes.append(extent)
#    1080             if tick.label2On and tick.label2.get_visible():
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     965             raise RuntimeError('Cannot get window extent w/o renderer')
#     966
# --> 967         bbox, info, descent = self._get_layout(self._renderer)
#     968         x, y = self.get_unitless_position()
#     969         x, y = self.get_transform().transform_point((x, y))
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     360                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     361                                                         self._fontproperties,
# --> 362                                                         ismath=ismath)
#     363             else:
#     364                 w, h, d = 0, 0, 0
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     233         if ismath:
#     234             ox, oy, width, height, descent, fonts, used_characters = \
# --> 235                 self.mathtext_parser.parse(s, self.dpi, prop)
#     236             return width, height, descent
#     237
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3271             fontset_class = self._font_type_mapping.get(fontset.lower())
#    3272             if fontset_class is not None:
# -> 3273                 font_output = fontset_class(prop, backend)
#    3274             else:
#    3275                 raise ValueError(
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/mathtext.py in __init__(self, *args, **kwargs)
#     903                  5 : 'STIXSizeFiveSym'})
#     904         for key, name in six.iteritems(self._fontmap):
# --> 905             fullpath = findfont(name)
#     906             self.fontmap[key] = fullpath
#     907             self.fontmap[name] = fullpath
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in findfont(prop, **kw)
#    1443     def findfont(prop, **kw):
#    1444         global fontManager
# -> 1445         font = fontManager.findfont(prop, **kw)
#    1446         return font
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in findfont(self, prop, fontext, directory, fallback_to_default, rebuild_if_missing)
#    1253         """
#    1254         if not isinstance(prop, FontProperties):
# -> 1255             prop = FontProperties(prop)
#    1256         fname = prop.get_file()
#    1257         if fname is not None:
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in __init__(self, family, style, variant, weight, stretch, size, fname, _init)
#     704                 size is None and
#     705                 fname is None):
# --> 706                 self.set_fontconfig_pattern(family)
#     707                 return
#     708
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in set_fontconfig_pattern(self, pattern)
#     925         for key, val in six.iteritems(self._parse_fontconfig_pattern(pattern)):
#     926             if type(val) == list:
# --> 927                 getattr(self, "set_" + key)(val[0])
#     928             else:
#     929                 getattr(self, "set_" + key)(val)
#
# /Users/zihengchen/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py in set_weight(self, weight)
#     862             if weight not in weight_dict:
#     863                 raise ValueError("weight is invalid")
# --> 864             weight = weight_dict[weight]
#     865         self._weight = weight
#     866
#
# KeyboardInterrupt:
