# %%
from utility_dfcutter import *
from utility_dfplotter import *
import utility_common as common
# %matplotlib inline

# %%
# emu
selection,nbjet,njet = 'emu','==1','>=2'

MCzz = DFCutter(selection, nbjet, 'mcdiboson',njet).getDataFrame('')
MCz  = DFCutter(selection, nbjet, 'mcz',      njet).getDataFrame('')
MCw  = DFCutter(selection, nbjet, 'mcw',      njet).getDataFrame('')
MCt  = DFCutter(selection, nbjet, 'mct',      njet).getDataFrame('')
MCtt = DFCutter(selection, nbjet, 'mctt',     njet).getDataFrame('')
mc = pd.concat([MCzz,MCz,MCw,MCt,MCtt],ignore_index=True)

        
data = DFCutter(selection,nbjet,'data2016', njet).getDataFrame(variation="")

v,a,b,step,xl = 'lepton2_pt',0,160,5, r'$p_{e}^T$ [GeV]'
mybin  = np.arange(a,b,step)
center = mybin[1:]-step/2

plt.figure(facecolor='w',figsize=(6,4))
hdata = np.histogram(data[v],mybin)[0]
plt.errorbar(center, hdata, yerr=hdata**0.5,color='k', label='data', fmt='.',markersize=10)

list_varable = [ data.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
list_weight = [ data.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]

mc_list_varable = [ mc.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
mc_list_weight = [ mc.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]
list_color = ['C3','C2','C1','C0']
plt.hist(mc_list_varable,mybin,weights=mc_list_weight,histtype='stepfilled',stacked=True, linewidth=0,alpha=0.3, color = list_color)
plt.hist(list_varable,mybin,weights=list_weight,histtype='step',stacked=True, linewidth=2, color = list_color, 
        label= [r'data, ($\mu, e$)',
                r'data, ($\mu,\mathbf{e}$)',
                r'data, ($\mathbf{\mu},e$)',
                r'data, ($\mathbf{\mu},\mathbf{e}$)'])
plt.legend(fontsize=12)
plt.text(0.04*b+0.96*a, hdata.max()*1.2, r'$\mu e$ channel $(n_j\geq 2,n_b=1 )$',style='italic',fontsize='12')
plt.ylim(0,hdata.max()*1.5)
plt.xlim(a,b)

plt.title('L=35.9/fb (13TeV)',loc='right')
plt.xlabel(xl,fontsize=12)
plt.grid(True,linestyle='--',alpha=0.5)
plt.text(0.04*b+0.96*a, 1.35*hdata.max(), r'CMS $preliminary$',style='italic',fontsize='15',fontweight='bold')
baseDir = common.getBaseDirectory()
plt.savefig(baseDir+'plots/trgLep_'+selection+'.png',dpi=300)

# %%
# mumu
selection,nbjet,njet = 'mumu','==1','>=2'
data = DFCutter(selection,nbjet,'data2016', njet).getDataFrame(variation="")
MCzz = DFCutter(selection, nbjet, 'mcdiboson',njet).getDataFrame('')
MCz  = DFCutter(selection, nbjet, 'mcz',      njet).getDataFrame('')
MCw  = DFCutter(selection, nbjet, 'mcw',      njet).getDataFrame('')
MCt  = DFCutter(selection, nbjet, 'mct',      njet).getDataFrame('')
MCtt = DFCutter(selection, nbjet, 'mctt',     njet).getDataFrame('')
mc = pd.concat([MCzz,MCz,MCw,MCt,MCtt],ignore_index=True)

v,a,b,step,xl = 'lepton2_pt',0,160,5, r'$p_{\mu2}^T$ [GeV]'
mybin  = np.arange(a,b,step)
center = mybin[1:]-step/2

plt.figure(facecolor='w',figsize=(6,4))
hdata = np.histogram(data[v],mybin)[0]
plt.errorbar(center, hdata, yerr=hdata**0.5,color='k', label='data', fmt='.',markersize=10)

list_varable = [ data.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
list_weight = [ data.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]

mc_list_varable = [ mc.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
mc_list_weight = [ mc.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]
list_color = ['C3','C2','C1','C0']
plt.hist(mc_list_varable,mybin,weights=mc_list_weight,histtype='stepfilled',stacked=True, linewidth=0,alpha=0.3, color = list_color)
plt.hist(list_varable,mybin,weights=list_weight,histtype='step',stacked=True, linewidth=2, color = list_color, 
        label= [r'data, ($\mu_1,\mu_2$)',
                r'data, ($\mu_1,\mathbf{\mu_2}$)',
                r'data, ($\mathbf{\mu_1},\mu_2$)',
                r'data, ($\mathbf{\mu_1},\mathbf{\mu_2}$)'])
plt.legend(fontsize=12)
plt.text(0.04*b+0.96*a, hdata.max()*1.2, r'$\mu \mu$ channel $(n_j\geq 2,n_b=1 )$',style='italic',fontsize='12')
plt.ylim(0,hdata.max()*1.5)
plt.xlim(a,b)

plt.title('L=35.9/fb (13TeV)',loc='right')
plt.xlabel(xl,fontsize=12)
plt.grid(True,linestyle='--',alpha=0.5)
plt.text(0.04*b+0.96*a, 1.35*hdata.max(), r'CMS $preliminary$',style='italic',fontsize='15',fontweight='bold')
baseDir = common.getBaseDirectory()
plt.savefig(baseDir+'plots/trgLep_'+selection+'.png',dpi=300)

# %%
selection,nbjet,njet = 'emu2','==1','>=2'
data = DFCutter(selection,nbjet,'data2016', njet).getDataFrame(variation="")
MCzz = DFCutter(selection, nbjet, 'mcdiboson',njet).getDataFrame('')
MCz  = DFCutter(selection, nbjet, 'mcz',      njet).getDataFrame('')
MCw  = DFCutter(selection, nbjet, 'mcw',      njet).getDataFrame('')
MCt  = DFCutter(selection, nbjet, 'mct',      njet).getDataFrame('')
MCtt = DFCutter(selection, nbjet, 'mctt',     njet).getDataFrame('')
mc = pd.concat([MCzz,MCz,MCw,MCt,MCtt],ignore_index=True)

v,a,b,step,xl = 'lepton1_pt',0,160,5, r'$p_{\mu}^T$ [GeV]'
mybin  = np.arange(a,b,step)
center = mybin[1:]-step/2

plt.figure(facecolor='w',figsize=(6,4))
hdata = np.histogram(data[v],mybin)[0]
plt.errorbar(center, hdata, yerr=hdata**0.5,color='k', label='data', fmt='.',markersize=10)

list_varable = [ data.query('trTest=={}'.format(i))[v] for i in [0,1,2,3] ]
list_weight = [ data.query('trTest=={}'.format(i))['eventWeight'] for i in [0,1,2,3] ]
mc_list_varable = [ mc.query('trTest=={}'.format(i))[v] for i in [0,1,2,3] ]
mc_list_weight = [ mc.query('trTest=={}'.format(i))['eventWeight'] for i in [0,1,2,3] ]
list_color = ['C3','C2','C1','C0']

plt.hist(mc_list_varable,mybin,weights=mc_list_weight,histtype='stepfilled',stacked=True, linewidth=0,alpha=0.3, color = list_color)
plt.hist(list_varable,mybin,weights=list_weight,histtype='step',stacked=True, linewidth=2, color = list_color, 
        label= [r'data, ($e, \mu$)',
                r'data, ($e,\mathbf{\mu}$)',
                r'data, ($\mathbf{e},\mu$)',
                r'data, ($\mathbf{e},\mathbf{\mu}$)'])
plt.legend(fontsize=12)
plt.text(0.04*b+0.96*a, hdata.max()*1.2, r'$e \mu$ channel $(n_j\geq 2,n_b=1 )$',style='italic',fontsize='12')
plt.ylim(0,hdata.max()*1.5)
plt.xlim(a,b)

plt.title('L=35.9/fb (13TeV)',loc='right')
plt.xlabel(xl,fontsize=12)
plt.grid(True,linestyle='--',alpha=0.5)
plt.text(0.04*b+0.96*a, 1.35*hdata.max(), r'CMS $preliminary$',style='italic',fontsize='15',fontweight='bold')
baseDir = common.getBaseDirectory()
plt.savefig(baseDir+'plots/trgLep_'+selection+'.png',dpi=300)

# %%
selection,nbjet,njet = 'ee','==1','>=2'
data = DFCutter(selection,nbjet,'data2016', njet).getDataFrame(variation="")
MCzz = DFCutter(selection, nbjet, 'mcdiboson',njet).getDataFrame('')
MCz  = DFCutter(selection, nbjet, 'mcz',      njet).getDataFrame('')
MCw  = DFCutter(selection, nbjet, 'mcw',      njet).getDataFrame('')
MCt  = DFCutter(selection, nbjet, 'mct',      njet).getDataFrame('')
MCtt = DFCutter(selection, nbjet, 'mctt',     njet).getDataFrame('')
mc = pd.concat([MCzz,MCz,MCw,MCt,MCtt],ignore_index=True)

v,a,b,step,xl = 'lepton2_pt',0,160,5, r'$p_{e2}^T$ [GeV]'
mybin  = np.arange(a,b,step)
center = mybin[1:]-step/2

plt.figure(facecolor='w',figsize=(6,4))
hdata = np.histogram(data[v],mybin)[0]
plt.errorbar(center, hdata, yerr=hdata**0.5,color='k', label='data', fmt='.',markersize=10)

list_varable = [ data.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
list_weight = [ data.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]

mc_list_varable = [ mc.query('trTest=={}'.format(i))[v] for i in [0,2,1,3] ]
mc_list_weight = [ mc.query('trTest=={}'.format(i))['eventWeight'] for i in [0,2,1,3] ]
list_color = ['C3','C2','C1','C0']

plt.hist(mc_list_varable,mybin,weights=mc_list_weight,histtype='stepfilled',stacked=True, linewidth=0,alpha=0.3, color = list_color)
plt.hist(list_varable,mybin,weights=list_weight,histtype='step',stacked=True, linewidth=2, color = list_color, 
        label= [r'data, ($e_1, e_2$)',
                r'data, ($e_1,\mathbf{e_2}$)',
                r'data, ($\mathbf{e_1},e_2$)',
                r'data, ($\mathbf{e_1},\mathbf{e_2}$)'])
plt.legend(fontsize=12)
plt.text(0.04*b+0.96*a, hdata.max()*1.2, r'$e e$ channel $(n_j\geq 2,n_b=1 )$',style='italic',fontsize='12')
plt.ylim(0,hdata.max()*1.5)
plt.xlim(a,b)

plt.title('L=35.9/fb (13TeV)',loc='right')
plt.xlabel(xl,fontsize=12)
plt.grid(True,linestyle='--',alpha=0.5)
plt.text(0.04*b+0.96*a, 1.35*hdata.max(), r'CMS $preliminary$',style='italic',fontsize='15',fontweight='bold')
baseDir = common.getBaseDirectory()
plt.savefig(baseDir+'plots/trgLep_'+selection+'.png',dpi=300)
