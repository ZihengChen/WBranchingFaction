# %%
from utility_dfplotter import *

# %%
folderOfPickles='pickles'
plotter = DFPlotter("mumu",">1", njet=None, folderOfPickles=folderOfPickles)

# %%
dfList = plotter.getDataFrameList()
# Out:
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/
# /home/zchen/Documents/Analysis/wbranch/data/pickles/mumu/

# %%
# v,a,b,step,xl = "lepton2_sip3d", 0, 30, 0.5, "lepton2_sip3d"
v,a,b,step,xl = "lepton2_d0", 0,0.05,0.001, "lepton2_d0"
sk = ASingleKinematicPlot(v,a,b,step,dfList,adjust=plotter.adjust)

sk.settingPlot(xl,plotter.labelList, plotter.colorList,logscale=False, withXsErr=False, subtitle=plotter.subtitle)
sk.makePlot(plotter.outputPlotDir, plotter.selection)


sk.settingPlot(xl,plotter.labelList, plotter.colorList,logscale=True, withXsErr=False, subtitle=plotter.subtitle)
sk.makePlot(plotter.outputPlotDir, plotter.selection)
